# %%
import intake
import pandas as pd
import pprint
import fsspec

import numpy as np
import xarray as xr
import xgcm
import xesmf as xe
import s3fs

import matplotlib.patches as mpatches

import cftime
import matplotlib.gridspec as gridspec

import matplotlib.pyplot as plt

import matplotlib
# %matplotlib inline

# %%
#ens1 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens1.nc')
#ens2 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens2.nc')
#ens3 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens3.nc')
#ens4 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens4.nc')
#ens5 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens5.nc')
#ens6 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens6.nc')
#ens7 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens7.nc')
#ens8 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens8.nc')
#ens9 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens9.nc')
#ens10 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens10.nc')
#ens11 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens11.nc')
#ens12 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens12.nc')
#ens13 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens13.nc')
#ens14 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens14.nc')
#ens15 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens15.nc')
#ens16 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens16.nc')
#ens17 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens17.nc')
#ens18 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens18.nc')
#ens19 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens19.nc')
#ens20 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens20.nc')
#ens21 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens21.nc')
#ens22 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens22.nc')
#ens23 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens23.nc')
#ens24 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens24.nc')
#ens25 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens25.nc')
#ens26 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens26.nc')
#ens27 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens27.nc')
#ens28 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens28.nc')
#ens29 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens29.nc')
#ens30 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens30.nc')
#ens31 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens31.nc')
#ens32 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens32.nc')
#ens33 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens33.nc')
#ens34 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens34.nc')
#ens35 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens35.nc')
#vel1 = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/vel1.nc')
#ensnum = 35
#ens_merged = xr.concat([ens1, ens2, ens3, ens4, ens5, ens6, ens7, ens8, ens9, ens10, ens11, ens12, 
#                        ens13, ens14, ens15, ens16, ens17, ens18, ens19, ens20, ens21, ens22, ens23, ens24, ens25, 
#                        ens26, ens27, ens28, ens29, ens30, ens31, ens32, ens33, ens34, ens35],dim='ens')

ens1 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens1.nc')
ens2 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens2.nc')
ens3 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens3.nc')
ens4 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens4.nc')
ens5 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens5.nc')
ens6 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens6.nc')
ens7 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens7.nc')
ens8 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens8.nc')
ens9 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens9.nc')
ens10 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens10.nc')
ens11 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens11.nc')
ens12 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens12.nc')
ens13 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens13.nc')
ens14 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens14.nc')
ens15 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens15.nc')
ens16 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens16.nc')
ens17 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens17.nc')
ens18 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens18.nc')
ens19 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens19.nc')
ens20 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens20.nc')
ens21 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens21.nc')
ens22 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens22.nc')
ens23 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens23.nc')
ens24 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens24.nc')
ens25 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens25.nc')
ens26 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens26.nc')
ens27 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens27.nc')
ens28 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens28.nc')
ens29 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens29.nc')
ens30 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens30.nc')
ens31 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens31.nc')
ens32 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens32.nc')
ens33 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens33.nc')
ens34 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens34.nc')
ens35 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens35.nc')
ens_merged = xr.concat([ens1, ens2, ens3, ens4, ens5, ens6, ens7, ens8, ens9, ens10, ens11, ens12, ens13,
                        ens14, ens15, ens16, ens17, ens18, ens19, ens20, ens21, ens22,ens23, ens24, ens25, 
                        ens26,ens27, ens28, ens29, ens30, ens31,ens32, ens33, ens34, ens35],dim='ens')
vel1 = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/vel1.nc')
ensnum = 35

#ens1 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens1.nc')
#ens2 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens2.nc')
#ens3 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens3.nc')
#ens4 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens4.nc')
#ens5 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens5.nc')#
#ens6 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens6.nc')
#ens7 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens7.nc')
#ens8 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens8.nc')
#ens9 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens9.nc')
#ens10 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens10.nc')
#ens11 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens11.nc')
#ens12 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens12.nc')
#ens13 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens13.nc')#
#ens14 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens14.nc')
#ens15 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens15.nc')
#ens16 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens16.nc')
#ens17 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens17.nc')
#ens18 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens18.nc')
#ens19 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens19.nc')
#ens20 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens20.nc')
#ens21 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens21.nc')
#ens22 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens22.nc')
#ens23 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens23.nc')
#ens24 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens24.nc')
#ens25 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens25.nc')
#ens26 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens26.nc')
#ens27 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens27.nc')
#ens28 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens28.nc')
#ens29 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens29.nc')
#ens30 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens30.nc')
#ens31 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens31.nc')
#ens32 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens32.nc')
#ens33 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens33.nc')
#ens34 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens34.nc')
#ens35 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens35.nc')
#vel1 = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S/vel1.nc')

#ens_merged = xr.concat([ens1, ens2, ens3, ens4, ens5, ens6, ens7, ens8, ens9, ens10, ens11, ens12, 
#                        ens13, ens14, ens15, ens16, ens17, ens18, ens19, ens20, ens21, ens22,
#                       ens23, ens24, ens25, ens26, ens27, ens28, ens29, ens30, ens31, ens32, 
#                       ens33, ens34, ens35],dim='ens')
#ensnum = 35

# %%
cum_mathz_gyre = ens_merged.mathz_gyre.mean('ens')
mean_polyfit_mathz_gyre = cum_mathz_gyre.polyfit(dim='time', deg=1)

cum_mathz_ot = ens_merged.mathz_ot.mean('ens')
mean_polyfit_mathz_ot = cum_mathz_ot.polyfit(dim='time', deg=1)

cum_net = ens_merged.net.mean('ens')
mean_polyfit_net = cum_net.polyfit(dim='time', deg=1)


cum_tot = ens_merged.tot.mean('ens')
mean_polyfit_tot = cum_tot.polyfit(dim='time', deg=1)


cum_mathd_gyre = ens_merged.mathd_gyre.mean('ens')
mean_polyfit_mathd_gyre = cum_mathd_gyre.polyfit(dim='time', deg=1)


cum_mathd_ot = ens_merged.mathd_ot.mean('ens')
mean_polyfit_mathd_ot = cum_mathd_ot.polyfit(dim='time', deg=1)


cum_west_gyre = ens_merged.west_gyre.mean('ens')
mean_polyfit_west_gyre = cum_west_gyre.polyfit(dim='time', deg=1)

cum_west_ot = ens_merged.west_ot.mean('ens')
mean_polyfit_west_ot = cum_west_ot.polyfit(dim='time', deg=1)

# %%
def detrend_mathz_gyre(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_mathz_gyre)
    return cum_ht-fit

def detrend_mathz_ot(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_mathz_ot)
    return cum_ht-fit

def detrend_net(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_net)
    return cum_ht-fit

def detrend_tot(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_tot)
    return cum_ht-fit

def detrend_mathd_gyre(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_mathd_gyre)
    return cum_ht-fit

def detrend_mathd_ot(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_mathd_ot)
    return cum_ht-fit

def detrend_west_gyre(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_west_gyre)
    return cum_ht-fit

def detrend_west_ot(cum_ht):
    fit = xr.polyval(cum_ht.time, mean_polyfit_west_ot)
    return cum_ht-fit

# %%
#d_mathz_gyre = detrend_mathz_gyre(ens_merged.mathz_gyre).polyfit_coefficients
#d_mathz_ot = detrend_mathz_ot(ens_merged.mathz_ot).polyfit_coefficients
#d_net = detrend_net(ens_merged.net).polyfit_coefficients
#d_tot = detrend_tot(ens_merged.tot).polyfit_coefficients
#d_mathd_gyre = detrend_mathd_gyre(ens_merged.mathd_gyre).polyfit_coefficients
#d_mathd_ot = detrend_mathd_ot(ens_merged.mathd_ot).polyfit_coefficients
#d_west_gyre = detrend_west_gyre(ens_merged.west_gyre).polyfit_coefficients
#d_west_ot = detrend_west_ot(ens_merged.west_ot).polyfit_coefficients


d_mathz_gyre = ens_merged.mathz_gyre
d_mathz_ot = ens_merged.mathz_ot
d_net = ens_merged.net
d_tot = ens_merged.tot
d_mathd_gyre = ens_merged.mathd_gyre
d_mathd_ot = ens_merged.mathd_ot
d_west_gyre = ens_merged.west_gyre
d_west_ot = ens_merged.west_ot
d_max_MOC = ens_merged.max_MOC

math_mean_gyre = d_mathz_gyre.mean('time')/d_tot.mean('time')
math_mean_ot = d_mathz_ot.mean('time')/d_tot.mean('time')

mathd_mean_gyre = d_mathd_gyre.mean('time')/d_tot.mean('time')
mathd_mean_ot = d_mathd_ot.mean('time')/d_tot.mean('time')

west_mean_gyre = d_west_gyre.mean('time')/d_tot.mean('time')
west_mean_ot = d_west_ot.mean('time')/d_tot.mean('time')

d_mathz_gyre_10 = ens_merged.mathz_gyre.rolling(time=10*12).mean()
d_mathz_ot_10 = ens_merged.mathz_ot.rolling(time=10*12).mean()
d_mathd_gyre_10 = ens_merged.mathd_gyre.rolling(time=10*12).mean()
d_mathd_ot_10 = ens_merged.mathd_ot.rolling(time=10*12).mean()
d_west_gyre_10 = ens_merged.west_gyre.rolling(time=10*12).mean()
d_west_ot_10 = ens_merged.west_ot.rolling(time=10*12).mean()
d_tot_10 = ens_merged.tot.rolling(time=10*12).mean()
d_max_MOC_10 = ens_merged.max_MOC.rolling(time=10*12).mean()

d_mathz_gyre = ens_merged.mathz_gyre-d_mathz_gyre_10
d_mathz_ot = ens_merged.mathz_ot-d_mathz_ot_10
#d_net = ens_merged.net
d_tot = ens_merged.tot-d_tot_10
d_mathd_gyre = ens_merged.mathd_gyre-d_mathd_gyre_10
d_mathd_ot = ens_merged.mathd_ot-d_mathd_ot_10 
d_west_gyre = ens_merged.west_gyre-d_west_gyre_10
d_west_ot = ens_merged.west_ot-d_west_ot_10
d_max_MOC = ens_merged.max_MOC-d_max_MOC_10


tot2 = d_tot-d_net
math_gyre = xr.cov(d_mathz_gyre,d_tot,dim="time")/xr.cov(d_tot,d_tot,dim="time")
math_ot = xr.cov(d_mathz_ot,d_tot,dim="time")/xr.cov(d_tot,d_tot,dim="time")
math_gyre_corr = xr.corr(d_max_MOC,d_mathz_gyre,dim='time')


math_gyre_10 = xr.cov(d_mathz_gyre_10,d_tot_10,dim="time")/xr.cov(d_tot_10,d_tot_10,dim="time")
math_ot_10 = xr.cov(d_mathz_ot_10,d_tot_10,dim="time")/xr.cov(d_tot_10,d_tot_10,dim="time")
math_gyre_corr_10 = xr.corr(d_max_MOC_10,d_mathz_gyre_10,dim='time')


mathd_gyre = xr.cov(d_mathd_gyre,d_tot,dim="time")/xr.cov(d_tot,d_tot,dim="time")
mathd_ot = xr.cov(d_mathd_ot,d_tot,dim="time")/xr.cov(d_tot,d_tot,dim="time")
mathd_gyre_corr = xr.corr(d_max_MOC,d_mathd_gyre,dim='time')


mathd_gyre_10 = xr.cov(d_mathd_gyre_10,d_tot_10,dim="time")/xr.cov(d_tot_10,d_tot_10,dim="time")
mathd_ot_10 = xr.cov(d_mathd_ot_10,d_tot_10,dim="time")/xr.cov(d_tot_10,d_tot_10,dim="time")
mathd_gyre_corr_10 = xr.corr(d_max_MOC_10,d_mathd_gyre_10,dim='time')

west_gyre = xr.cov(d_west_gyre,d_tot,dim="time")/xr.cov(d_tot,d_tot,dim="time")
west_ot = xr.cov(d_west_ot,d_tot,dim="time")/xr.cov(d_tot,d_tot,dim="time")
west_gyre_corr = xr.corr(d_max_MOC,d_west_gyre,dim='time')


west_gyre_10 = xr.cov(d_west_gyre_10,d_tot_10,dim="time")/xr.cov(d_tot_10,d_tot_10,dim="time")
west_ot_10 = xr.cov(d_west_ot_10,d_tot_10,dim="time")/xr.cov(d_tot_10,d_tot_10,dim="time")
west_gyre_corr_10 = xr.corr(d_max_MOC_10,d_west_gyre_10,dim='time')


df1 = pd.DataFrame({'overturning1':math_ot.values,'gyre1':math_gyre.values,'gcorr1':math_gyre_corr.values,
                    'mgyre1':math_mean_gyre.values,'mot1':math_mean_ot.values, 'overturning1_10':math_ot_10.values,
                   'gyre1_10':math_gyre_10.values,'gcorr1_10':math_gyre_corr_10.values},index =np.arange(1,ensnum+1)) 
#df1.plot.bar()



df2 = pd.DataFrame({'overturning2':mathd_ot.values,'gyre2':mathd_gyre.values,'gcorr2':mathd_gyre_corr.values,
                    'mgyre2':mathd_mean_gyre.values,'mot2':mathd_mean_ot.values,'overturning2_10':mathd_ot_10.values,
                    'gyre2_10':mathd_gyre_10.values, 'gcorr2_10':mathd_gyre_corr_10.values},index =np.arange(1,ensnum+1)) 
#df2.plot.bar()

df=df1.join(df2)


df3 = pd.DataFrame({'overturning3':west_ot.values,'gyre3':west_gyre.values,'gcorr3':west_gyre_corr.values,
                    'mgyre3':west_mean_gyre.values,'mot3':west_mean_ot.values, 'overturning3_10':west_ot_10.values,
                    'gyre3_10':west_gyre_10.values,'gcorr3_10':west_gyre_corr_10.values},index =np.arange(1,ensnum+1)) 
#df2.plot.bar()

df=df.join(df3)

# %%
import matplotlib.patches as mpatches

matplotlib.rcParams.update({'font.size': 14})

fig=plt.figure(figsize=(18,5))

gs0 = gridspec.GridSpec(2, 4, figure=fig)


boxprops = dict(linewidth=2.0, color='black')
whiskerprops = dict(linestyle='-',linewidth=2.0, color='black')
medianprops = dict(linestyle='-',linewidth=2.0, color='black')
capprops = dict(linestyle='-',linewidth=2.0, color='black')
ax7 = fig.add_subplot(gs0[:, 2])
ax1,row = df[['overturning1','overturning2','overturning3']].boxplot(patch_artist=True,rot=45,figsize=(6, 8),return_type='both',
                     boxprops=boxprops, whiskerprops=whiskerprops, medianprops=medianprops, capprops=capprops)

colors = ['tab:green', 'tab:pink', 'tab:blue']
for i,box in enumerate(row['boxes']):
    box.set_facecolor(colors[i])
    
#green_patch = mpatches.Patch(color='tab:green', label='Z-space')
#pink_patch = mpatches.Patch(color='tab:pink', label='Density space')
#blue_patch = mpatches.Patch(color='tab:blue', label='SF-splitting')
#plt.legend(handles=[green_patch, pink_patch,blue_patch])
plt.xticks([1, 2, 3], ['Z-space','Dens-space','SF'],ha='right')

ax1.set_ylabel('Proportion of variance explained')
plt.title('Proportion of 2-10yr OHT \n variance explained by MOC',fontsize=14)

#plt.axhline(0.84,color='grey')

plt.ylim(0,1.5)
plt.text(-0.1, 1.5, 'c',fontsize=14,fontweight='bold')


ax3 = fig.add_subplot(gs0[:, 3])
ax1,row = df[['overturning1_10','overturning2_10','overturning3_10']].boxplot(patch_artist=True,rot=45,figsize=(6, 8),return_type='both',
                     boxprops=boxprops, whiskerprops=whiskerprops, medianprops=medianprops, capprops=capprops)

colors = ['tab:green', 'tab:pink', 'tab:blue']
for i,box in enumerate(row['boxes']):
    box.set_facecolor(colors[i])
    
#green_patch = mpatches.Patch(color='tab:green', label='Z-space')
#pink_patch = mpatches.Patch(color='tab:pink', label='Density space')
#blue_patch = mpatches.Patch(color='tab:blue', label='SF-splitting')
#plt.legend(handles=[green_patch, pink_patch,blue_patch])
plt.xticks([1, 2, 3], ['Z-space','Dens-space','SF'],ha='right')

ax1.set_ylabel('Proportion of variance explained')
plt.title('Proportion of 10+yr OHT \n variance explained by MOC',fontsize=14)

#plt.axhline(0.92,color='grey')

plt.ylim(0,1.5)
plt.text(-0.1, 1.5, 'd',fontsize=14,fontweight='bold')

ax1 = fig.add_subplot(gs0[0, 0:2])


plt.title('Time-mean meridional velocity at 34N (m/s)')
lon_corr = vel1.ULONG.values
lon_corr[lon_corr>240]=lon_corr[lon_corr>240]-360

cs=ax1.contourf(lon_corr,vel1.z_t.isel(z_t=slice(0,45))/100, 
             vel1.VVEL.isel(z_t=slice(0,45))/100,cmap='seismic',levels=np.arange(-1,1,0.01)*0.3,extend='both')#
#plt.contour(lon_corr,vs.z_t.isel(z_t=slice(0,45))/100, 
#             ds.TEMP.sel(nlat=latit).sel(member_id=pick_id).mean('time')
#                .isel(z_t=slice(0,45),nlon=slice(33,76)),levels=np.arange(5,26,5),colors='grey',extend='both')
ax1.plot(lon_corr,vel1.thickness,'k')
#ax1.axvline(vel1.median_long)

lons1 = np.concatenate((np.expand_dims(vel1.median_long.values,axis=0), np.expand_dims(vel1.median_long,axis=0)
                        ,lon_corr[5:]))
depths1 = np.concatenate((np.asarray([0]), vel1.thickness[4:].values))
ax1.add_patch(mpatches.Polygon(xy=np.asarray([lons1, depths1]).T,
                                    alpha=1, facecolor='none',ls='-',lw=2,ec='k', hatch='\\'))

mask1 = xr.ones_like(vel1.VVEL.isel(z_t=slice(0,45)))
mask1 = mask1.where(~np.isnan(vel1.VVEL.isel(z_t=slice(0,45))),0)
plt.contour(lon_corr,vel1.z_t.isel(z_t=slice(0,45))/100, mask1,levels=[-1,0.99],colors='grey',linewidths=3)
plt.gca().invert_yaxis()
plt.ylim(1400,0)
plt.gca().axes.xaxis.set_ticklabels([])
#plt.xlabel('Longitude')
plt.ylabel('Depth (m)')
plt.text(-85, 10, 'a',fontsize=14,fontweight='bold')

ax2 = fig.add_subplot(gs0[1, 0:2])

lon_corr = vel1.ULONG.values
lon_corr[lon_corr>240]=lon_corr[lon_corr>240]-360

cs=plt.contourf(lon_corr,vel1.z_t.isel(z_t=slice(40,90))/100, 
             vel1.VVEL.isel(z_t=slice(40,90))/100,cmap='seismic',levels=np.arange(-1,1,0.01)*0.3,extend='both')#
#plt.contour(lon_corr,vs.z_t.isel(z_t=slice(0,45))/100, 
#             ds.TEMP.sel(nlat=latit).sel(member_id=pick_id).mean('time')
#                .isel(z_t=slice(0,45),nlon=slice(33,76)),levels=np.arange(5,26,5),colors='grey',extend='both')
#plt.plot(lon_corr,vel1.thickness,'k')
#plt.axvline(vel1.median_long)

mask1 = xr.ones_like(vel1.VVEL.isel(z_t=slice(40,90)))
mask1 = mask1.where(~np.isnan(vel1.VVEL.isel(z_t=slice(40,90))),0)
plt.contour(lon_corr,vel1.z_t.isel(z_t=slice(40,90))/100, mask1,levels=[-1,0.99],colors='grey',linewidths=3)
cbaxes = ax2.inset_axes([0.46, 0.17, 0.25, 0.05]) 
plt.colorbar(cs,cax=cbaxes,orientation='horizontal',ticks=[-0.3, 0, 0.3])
plt.gca().invert_yaxis()
#plt.colorbar(cs)
plt.ylim(5500,1400)
plt.xlabel('Longitude')
plt.ylabel('Depth (m)')
plt.text(-85, 1610, 'b',fontsize=14,fontweight='bold')


plt.subplots_adjust(wspace=0.5, hspace=0.1,bottom=0.2)

plt.savefig('methods_comparison_34N.png')

# %%
matplotlib.rcParams.update({'font.size': 14})

median_long = ens_merged.long_1.isel(ens=0).median()

fig=plt.figure(figsize=(18,5))

gs0 = gridspec.GridSpec(2, 4, figure=fig)


boxprops = dict(linewidth=2.0, color='black')
whiskerprops = dict(linestyle='-',linewidth=2.0, color='black')
medianprops = dict(linestyle='-',linewidth=2.0, color='black')
capprops = dict(linestyle='-',linewidth=2.0, color='black')
ax7 = fig.add_subplot(gs0[:, 2])
ax1,row = df[['overturning1','overturning2','overturning3']].boxplot(patch_artist=True,rot=45,figsize=(6, 8),return_type='both',
                     boxprops=boxprops, whiskerprops=whiskerprops, medianprops=medianprops, capprops=capprops)

colors = ['tab:green', 'tab:pink', 'tab:blue']
for i,box in enumerate(row['boxes']):
    box.set_facecolor(colors[i])
    
#green_patch = mpatches.Patch(color='tab:green', label='Z-space')
#pink_patch = mpatches.Patch(color='tab:pink', label='Density space')
#blue_patch = mpatches.Patch(color='tab:blue', label='SF-splitting')
#plt.legend(handles=[green_patch, pink_patch,blue_patch])
plt.xticks([1, 2, 3], ['Z-space','Dens.-space','SF'],ha='right')

ax1.set_ylabel('Proportion of variance explained')
plt.title('Proportion of 2-10yr OHT \n variance explained by MOC',fontsize=14)


#plt.axhline(0.92,color='grey')
plt.ylim(0,1.5)
plt.text(-0.1, 1.5, 'c',fontsize=14,fontweight='bold')


ax3 = fig.add_subplot(gs0[:, 3])
ax1,row = df[['overturning1_10','overturning2_10','overturning3_10']].boxplot(patch_artist=True,rot=45,figsize=(6, 8),return_type='both',
                     boxprops=boxprops, whiskerprops=whiskerprops, medianprops=medianprops, capprops=capprops)

colors = ['tab:green', 'tab:pink', 'tab:blue']
for i,box in enumerate(row['boxes']):
    box.set_facecolor(colors[i])
    
#green_patch = mpatches.Patch(color='tab:green', label='Z-space')
#pink_patch = mpatches.Patch(color='tab:pink', label='Density space')
#blue_patch = mpatches.Patch(color='tab:blue', label='SF-splitting')
#plt.legend(handles=[green_patch, pink_patch,blue_patch])
plt.xticks([1, 2, 3], ['Z-space','Dens.-space','SF'],ha='right')

#plt.axhline(0.9,color='grey')

ax1.set_ylabel('Proportion of variance explained')
plt.title('Proportion of 10+yr OHT \n variance explained by MOC',fontsize=14)

plt.ylim(0,1.5)


plt.text(-0.1, 1.5, 'd',fontsize=14,fontweight='bold')

ax1 = fig.add_subplot(gs0[0, 0:2])


plt.title('Time-mean meridional velocity at 26N (m/s)')
lon_corr = vel1.ULONG.values
lon_corr[lon_corr>240]=lon_corr[lon_corr>240]-360



cs=ax1.contourf(lon_corr,vel1.z_t.isel(z_t=slice(0,45))/100, 
             vel1.VVEL.isel(z_t=slice(0,45))/100,cmap='seismic',levels=np.arange(-1,1,0.01)*0.3,extend='both')#
#plt.contour(lon_corr,vs.z_t.isel(z_t=slice(0,45))/100, 
#             ds.TEMP.sel(nlat=latit).sel(member_id=pick_id).mean('time')
#                .isel(z_t=slice(0,45),nlon=slice(33,76)),levels=np.arange(5,26,5),colors='grey',extend='both')
ax1.plot(lon_corr,vel1.thickness,'k')
#ax1.axvline(vel1.median_long)


lon_corr2 = vel1.ULONG.values
lon_corr2[lon_corr2>240]=lon_corr2[lon_corr2>240]-360
lons1 = np.concatenate((np.expand_dims(median_long.values,axis=0), np.expand_dims(median_long.values,axis=0)
                        ,lon_corr[4:]))
depths1 = np.concatenate((np.asarray([0]), vel1.thickness[3:].values))
ax1.add_patch(mpatches.Polygon(xy=np.asarray([lons1, depths1]).T,
                                    alpha=1, facecolor='none',ls='-',lw=2,ec='k', hatch='\\'))

mask1 = xr.ones_like(vel1.VVEL.isel(z_t=slice(0,45)))
mask1 = mask1.where(~np.isnan(vel1.VVEL.isel(z_t=slice(0,45))),0)
plt.contour(lon_corr,vel1.z_t.isel(z_t=slice(0,45))/100, mask1,levels=[-1,0.99],colors='grey',linewidths=3)
plt.gca().invert_yaxis()
plt.ylim(1400,0)
plt.gca().axes.xaxis.set_ticklabels([])
#plt.xlabel('Longitude')
plt.ylabel('Depth (m)')
plt.xlim(-83,-10)
plt.text(-90, 10, 'a',fontsize=14,fontweight='bold')

ax2 = fig.add_subplot(gs0[1, 0:2])

lon_corr = vel1.ULONG.values
lon_corr[lon_corr>240]=lon_corr[lon_corr>240]-360

cs=plt.contourf(lon_corr,vel1.z_t.isel(z_t=slice(40,90))/100, 
             vel1.VVEL.isel(z_t=slice(40,90))/100,cmap='seismic',levels=np.arange(-1,1,0.01)*0.3,extend='both')#
#plt.contour(lon_corr,vs.z_t.isel(z_t=slice(0,45))/100, 
#             ds.TEMP.sel(nlat=latit).sel(member_id=pick_id).mean('time')
#                .isel(z_t=slice(0,45),nlon=slice(33,76)),levels=np.arange(5,26,5),colors='grey',extend='both')
#plt.plot(lon_corr,vel1.thickness,'k')
#plt.axvline(vel1.median_long)

mask1 = xr.ones_like(vel1.VVEL.isel(z_t=slice(40,90)))
mask1 = mask1.where(~np.isnan(vel1.VVEL.isel(z_t=slice(40,90))),0)
plt.contour(lon_corr,vel1.z_t.isel(z_t=slice(40,90))/100, mask1,levels=[-1,0.99],colors='grey',linewidths=3)
cbaxes = ax2.inset_axes([0.15, 0.17, 0.25, 0.05]) 
plt.colorbar(cs,cax=cbaxes,orientation='horizontal',ticks=[-0.3, 0, 0.3])
plt.gca().invert_yaxis()
#plt.colorbar(cs)
plt.ylim(5500,1400)
plt.xlim(-83,-10)
plt.xlabel('Longitude')
plt.ylabel('Depth (m)')
plt.text(-90, 1610, 'b',fontsize=14,fontweight='bold')


plt.subplots_adjust(wspace=0.5, hspace=0.1,bottom=0.2)

plt.savefig('methods_comparison_26N.png')

# %%
matplotlib.rcParams.update({'font.size': 14})

fig=plt.figure(figsize=(18,5))

gs0 = gridspec.GridSpec(2, 4, figure=fig)


boxprops = dict(linewidth=2.0, color='black')
whiskerprops = dict(linestyle='-',linewidth=2.0, color='black')
medianprops = dict(linestyle='-',linewidth=2.0, color='black')
capprops = dict(linestyle='-',linewidth=2.0, color='black')
ax7 = fig.add_subplot(gs0[:, 2])
ax1,row = df[['overturning1','overturning2','overturning3']].boxplot(patch_artist=True,rot=45,figsize=(6, 8),return_type='both',
                     boxprops=boxprops, whiskerprops=whiskerprops, medianprops=medianprops, capprops=capprops)

colors = ['tab:green', 'tab:pink', 'tab:blue']
for i,box in enumerate(row['boxes']):
    box.set_facecolor(colors[i])
    
#green_patch = mpatches.Patch(color='tab:green', label='Z-space')
#pink_patch = mpatches.Patch(color='tab:pink', label='Density space')
#blue_patch = mpatches.Patch(color='tab:blue', label='SF-splitting')
#plt.legend(handles=[green_patch, pink_patch,blue_patch])
plt.xticks([1, 2, 3], ['Z-space','Dens.-space','SF'],ha='right')

ax1.set_ylabel('Proportion of variance explained')
plt.title('Proportion of 2-10yr OHT \n variance explained by MOC',fontsize=14)

#plt.axhline(0.71,color='grey')

plt.ylim(0, 1.3)
plt.text(-0.1, 1.3, 'c',fontsize=14,fontweight='bold')


ax3 = fig.add_subplot(gs0[:, 3])
ax1,row = df[['overturning1_10','overturning2_10','overturning3_10']].boxplot(patch_artist=True,rot=45,figsize=(6, 8),return_type='both',
                     boxprops=boxprops, whiskerprops=whiskerprops, medianprops=medianprops, capprops=capprops)

colors = ['tab:green', 'tab:pink', 'tab:blue']
for i,box in enumerate(row['boxes']):
    box.set_facecolor(colors[i])
    
#green_patch = mpatches.Patch(color='tab:green', label='Z-space')
#pink_patch = mpatches.Patch(color='tab:pink', label='Density space')
#blue_patch = mpatches.Patch(color='tab:blue', label='SF-splitting')
#plt.legend(handles=[green_patch, pink_patch,blue_patch])
plt.xticks([1, 2, 3], ['Z-space','Dens.-space','SF'],ha='right')

ax1.set_ylabel('Proportion of variance explained')
plt.title('Proportion of 10+yr OHT \n variance explained by MOC',fontsize=14)

#plt.axhline(0.88,color='grey')

plt.ylim(0, 1.3)


#plt.ylim(-0.3,1.6)
plt.text(-0.1, 1.3, 'd',fontsize=14,fontweight='bold')

ax1 = fig.add_subplot(gs0[0, 0:2])


plt.title('Time-mean meridional velocity at 5S (m/s)')
lon_corr = vel1.ULONG.values
lon_corr[lon_corr>300]=lon_corr[lon_corr>300]-360

cs=plt.contourf(lon_corr,vel1.z_t.isel(z_t=slice(0,45))/100, 
             vel1.VVEL.isel(z_t=slice(0,45))/100,cmap='seismic',levels=np.arange(-1,1,0.01)*0.3,extend='both')#
#plt.contour(lon_corr,vs.z_t.isel(z_t=slice(0,45))/100, 
#             ds.TEMP.sel(nlat=latit).sel(member_id=pick_id).mean('time')
#                .isel(z_t=slice(0,45),nlon=slice(33,76)),levels=np.arange(5,26,5),colors='grey',extend='both')
lon_corr2 = vel1.ULONG.values
lon_corr2[lon_corr2>240]=lon_corr2[lon_corr2>240]-360
lons1 = np.concatenate((np.expand_dims(vel1.median_long.values,axis=0), np.expand_dims(vel1.median_long,axis=0)
                        ,lon_corr2[4:]))
depths1 = np.concatenate((np.asarray([0]), vel1.thickness[3:].values))
ax1.add_patch(mpatches.Polygon(xy=np.asarray([lons1, depths1]).T,
                                    alpha=1, facecolor='none',ls='-',lw=2,ec='k', hatch='\\'))
mask1 = xr.ones_like(vel1.VVEL.isel(z_t=slice(0,45)))
mask1 = mask1.where(~np.isnan(vel1.VVEL.isel(z_t=slice(0,45))),0)
plt.contour(lon_corr,vel1.z_t.isel(z_t=slice(0,45))/100, mask1,levels=[-1,0.99],colors='grey',linewidths=3)

plt.plot(lon_corr,vel1.thickness,'k')
#plt.axvline(vel1.median_long)
plt.gca().invert_yaxis()
plt.ylim(1600,0)
plt.gca().axes.xaxis.set_ticklabels([])
#plt.xlabel('Longitude')
plt.ylabel('Depth (m)')
plt.text(-40, 10, 'a',fontsize=14,fontweight='bold')

ax2 = fig.add_subplot(gs0[1, 0:2])

lon_corr = vel1.ULONG.values
lon_corr[lon_corr>300]=lon_corr[lon_corr>300]-360

cs=plt.contourf(lon_corr,vel1.z_t.isel(z_t=slice(40,90))/100, 
             vel1.VVEL.isel(z_t=slice(40,90))/100,cmap='seismic',levels=np.arange(-1,1,0.01)*0.3,extend='both')#
#plt.contour(lon_corr,vs.z_t.isel(z_t=slice(0,45))/100, 
#             ds.TEMP.sel(nlat=latit).sel(member_id=pick_id).mean('time')
#                .isel(z_t=slice(0,45),nlon=slice(33,76)),levels=np.arange(5,26,5),colors='grey',extend='both')
#plt.plot(lon_corr,vel1.thickness,'k')
#plt.axvline(vel1.median_long)
mask1 = xr.ones_like(vel1.VVEL.isel(z_t=slice(40,90)))
mask1 = mask1.where(~np.isnan(vel1.VVEL.isel(z_t=slice(40,90))),0)
plt.contour(lon_corr,vel1.z_t.isel(z_t=slice(40,90))/100, mask1,levels=[-1,0.99],colors='grey',linewidths=3)

cbaxes = ax2.inset_axes([0.35, 0.2, 0.25, 0.05]) 
plt.colorbar(cs,cax=cbaxes,orientation='horizontal',ticks=[-0.3, 0, 0.3])
plt.gca().invert_yaxis()
#plt.colorbar(cs)
plt.ylim(5500,1600)
plt.xlabel('Longitude')
plt.ylabel('Depth (m)')
plt.text(-40, 1610, 'b',fontsize=14,fontweight='bold')




plt.subplots_adjust(wspace=0.4, hspace=0.1,bottom=0.22)

plt.savefig('methods_comparison_5S.png')
