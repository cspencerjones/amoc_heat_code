# %%
import intake
import pandas as pd
import pprint
import fsspec

import numpy as np
import xarray as xr
import xgcm
import xesmf as xe
import s3fs

import matplotlib.patches as mpatches

import cftime
import matplotlib.gridspec as gridspec

import matplotlib.pyplot as plt

import matplotlib
# %matplotlib inline

# %%
ens1_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens1.nc')
ens2_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens2.nc')
ens3_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens3.nc')
ens4_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens4.nc')
ens5_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens5.nc')
ens6_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens6.nc')
ens7_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens7.nc')
ens8_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens8.nc')
ens9_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens9.nc')
ens10_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens10.nc')
ens11_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens11.nc')
ens12_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens12.nc')
ens13_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens13.nc')
ens14_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens14.nc')
ens15_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens15.nc')
ens16_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens16.nc')
ens17_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens17.nc')
ens18_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens18.nc')
ens19_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens19.nc')
ens20_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens20.nc')
ens21_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens21.nc')
ens22_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens22.nc')
ens23_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens23.nc')
ens24_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens24.nc')
ens25_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens25.nc')
ens26_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens26.nc')
ens27_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens27.nc')
ens28_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens28.nc')
ens29_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens29.nc')
ens30_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens30.nc')
ens31_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens31.nc')
ens32_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens32.nc')
ens33_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens33.nc')
ens34_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens34.nc')
ens35_34N = xr.open_dataset('/home/jovyan/amoc_heat_transport/34N_nocum/compnd_ens35.nc')

ens1_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens1.nc')
ens2_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens2.nc')
ens3_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens3.nc')
ens4_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens4.nc')
ens5_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens5.nc')
ens6_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens6.nc')
ens7_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens7.nc')
ens8_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens8.nc')
ens9_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens9.nc')
ens10_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens10.nc')
ens11_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens11.nc')
ens12_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens12.nc')
ens13_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens13.nc')
ens14_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens14.nc')
ens15_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens15.nc')
ens16_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens16.nc')
ens17_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens17.nc')
ens18_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens18.nc')
ens19_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens19.nc')
ens20_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens20.nc')
ens21_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens21.nc')
ens22_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens22.nc')
ens23_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens23.nc')
ens24_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens24.nc')
ens25_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens25.nc')
ens26_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens26.nc')
ens27_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens27.nc')
ens28_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens28.nc')
ens29_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens29.nc')
ens30_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens30.nc')
ens31_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens31.nc')
ens32_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens32.nc')
ens33_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens33.nc')
ens34_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens34.nc')
ens35_26N = xr.open_dataset('/home/jovyan/amoc_heat_transport/26N_nocum/compnd_ens35.nc')

ens1_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens1.nc')
ens2_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens2.nc')
ens3_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens3.nc')
ens4_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens4.nc')
ens5_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens5.nc')
ens6_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens6.nc')
ens7_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens7.nc')
ens8_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens8.nc')
ens9_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens9.nc')
ens10_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens10.nc')
ens11_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens11.nc')
ens12_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens12.nc')
ens13_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens13.nc')
ens14_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens14.nc')
ens15_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens15.nc')
ens16_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens16.nc')
ens17_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens17.nc')
ens18_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens18.nc')
ens19_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens19.nc')
ens20_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens20.nc')
ens21_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens21.nc')
ens22_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens22.nc')
ens23_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens23.nc')
ens24_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens24.nc')
ens25_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens25.nc')
ens26_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens26.nc')
ens27_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens27.nc')
ens28_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens28.nc')
ens29_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens29.nc')
ens30_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens30.nc')
ens31_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens31.nc')
ens32_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens32.nc')
ens33_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens33.nc')
ens34_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens34.nc')
ens35_5S = xr.open_dataset('/home/jovyan/amoc_heat_transport/5S_nocum/compnd_ens35.nc')

# %%
ens_merged_34N = xr.concat([ens1_34N, ens2_34N, ens3_34N, ens4_34N, ens5_34N, ens6_34N, ens7_34N, ens8_34N,
                            ens9_34N, ens10_34N, ens11_34N, ens12_34N, ens13_34N, ens14_34N, ens15_34N, ens16_34N,
                           ens17_34N, ens18_34N, ens19_34N, ens20_34N, ens21_34N, ens22_34N, ens23_34N, ens24_34N,
                           ens25_34N, ens26_34N, ens27_34N, ens28_34N, ens29_34N, ens30_34N, ens31_34N, ens32_34N,
                           ens33_34N, ens34_34N, ens35_34N],dim='ens')


ens_merged_26N = xr.concat([ens1_26N, ens2_26N, ens3_26N, ens4_26N, ens5_26N, ens6_26N, ens7_26N, ens8_26N, 
                           ens9_26N, ens10_26N, ens11_26N, ens12_26N, ens13_26N, ens14_26N, ens15_26N,
                           ens16_26N, ens17_26N, ens18_26N, ens19_26N, ens20_26N, ens21_26N, ens22_26N, 
                            ens23_26N, ens24_26N,ens25_26N, ens26_26N, ens27_26N, ens28_26N, ens29_26N, 
                            ens30_26N, ens31_26N, ens32_26N, ens33_26N, ens34_26N,ens35_26N],dim='ens')
ens_merged_5S = xr.concat([ens1_5S, ens2_5S, ens3_5S, ens4_5S, ens5_5S, ens6_5S, ens7_5S, ens8_5S, ens9_5S,
                          ens10_5S, ens11_5S, ens12_5S, ens13_5S, ens14_5S, ens15_5S, ens16_5S, ens17_5S,
                          ens18_5S, ens19_5S, ens20_5S, ens21_5S, ens22_5S, ens23_5S, ens24_5S, ens25_5S, 
                           ens26_5S, ens27_5S, ens28_5S, ens29_5S, ens30_5S, ens31_5S, ens32_5S, ens33_5S,
                          ens33_5S, ens34_5S, ens35_5S],dim='ens')

# %%
ens_merged_34N.long_1.to_dataset(name='lon_34N').to_netcdf('/home/jovyan/amoc_heat_transport/long_34N.nc')

# %%
matplotlib.rcParams.update({'font.size': 12})
fig = plt.figure(figsize=(3.5,6))

plt.subplot(311)

plt.hist(np.ravel(ens_merged_34N.long_1.dropna(dim='time').values), bins='auto') 

plt.ylabel('Frequency')
plt.grid()
plt.xlim(-75,-74.65)
plt.text(-74.72, 850, '34N',fontsize=14)


plt.subplot(312)

plt.hist(np.ravel(ens_merged_26N.long_1.dropna(dim='time').values), bins='auto') 

plt.ylabel('Frequency')
plt.grid()
plt.text(-77.97, 850, '26N',fontsize=14)

plt.subplot(313)

plt.hist(np.ravel(ens_merged_5S.long_1.dropna(dim='time').values), bins='auto') 
plt.xlabel('Longitude of $x^*$')
plt.ylabel('Frequency')
plt.grid()
plt.text(-33.07, 1250, '5S',fontsize=14)

plt.subplots_adjust(hspace=0.3,left=0.25)
plt.savefig('hist.png')
